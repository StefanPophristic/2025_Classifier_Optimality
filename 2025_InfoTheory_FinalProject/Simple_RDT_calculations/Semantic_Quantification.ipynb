# %% [markdown]
# Stefan Pophristic + Boxuan Li
# May 1st, 2025
# Information Theory Project
#
# Calculate Semantic Vector values for:
# - Nouns
# - Measure Words
# - Centroids for nouns that take the same MW

# %% [markdown]
# # Parameters

# %%
import pandas as pd
import fasttext
import os 
from gensim.models import KeyedVectors
import seaborn as sns

import numpy as np
from numpy import dot
from numpy.linalg import norm

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# Out:
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_43431/1568232499.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Import files 

noun_mw_df = pd.read_csv("../chinese_noun_mw.csv")

# %%
noun_mw_df.head()
# Out:
#   Noun MW  Count_Pre  Count_Post
# 0   上午  日          1           0
# 1   下半  局          1           0
# 2   下旬  年          1           0
# 3   下旬  月          2           0
# 4   下颌  个          1           0

# %%
all_nouns = noun_mw_df["Noun"].unique()
all_mw    = noun_mw_df["MW"].unique()

print(f"Number of unique nouns: {len(all_nouns)}")
print(f"Number of unique mw: {len(all_mw)}")
# Out:
# Number of unique nouns: 847
# Number of unique mw: 110

# %%
mw_summary_df = noun_mw_df.groupby('MW')['Count_Pre'].sum().reset_index()
mw_summary_df = mw_summary_df.sort_values(by='Count_Pre', ascending=False)

# %%
mw_summary_df
# Out:
#     MW  Count_Pre
# 2    个        547
# 50   年        517
# 64   月        373
# 84   种        129
# 74   次         69
# ..  ..        ...
# 56   手          1
# 28   壶          1
# 53  座座          1
# 30   天          1
# 10  公里          0
#
# [110 rows x 2 columns]

# %%
count_eq_1 = (mw_summary_df['Count_Pre'] == 1).sum()
count_eq_2 = (mw_summary_df['Count_Pre'] == 2).sum()
count_eq_3 = (mw_summary_df['Count_Pre'] == 3).sum()

print(f"Number of MW with only 1 noun: {count_eq_1}")
print(f"Number of MW with only 2 noun: {count_eq_2}")
print(f"Number of MW with only 3 noun: {count_eq_3}")
# Out:
# Number of MW with only 1 noun: 38
# Number of MW with only 2 noun: 10
# Number of MW with only 3 noun: 15

# %%
# Import Mandarin Fasttext
model = KeyedVectors.load_word2vec_format('/Volumes/server/SHARED/Corpora/FastText/Mandarin/cc.zh.300.vec', binary=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Import Mandarin Fasttext
# ----> 2 model = KeyedVectors.load_word2vec_format('/Volumes/server/SHARED/Corpora/FastText/Mandarin/cc.zh.300.vec', binary=False)
#
# File ~/miniconda3/lib/python3.11/site-packages/gensim/models/keyedvectors.py:1719, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1672 @classmethod
#    1673 def load_word2vec_format(
#    1674         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1675         limit=None, datatype=REAL, no_header=False,
#    1676     ):
#    1677     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1678
#    1679     Warnings
#    (...)
#    1717
#    1718     """
# -> 1719     return _load_word2vec_format(
#    1720         cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1721         limit=limit, datatype=datatype, no_header=no_header,
#    1722     )
#
# File ~/miniconda3/lib/python3.11/site-packages/gensim/models/keyedvectors.py:2069, in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2065         _word2vec_read_binary(
#    2066             fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding
#    2067         )
#    2068     else:
# -> 2069         _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#    2070 if kv.vectors.shape[0] != len(kv):
#    2071     logger.info(
#    2072         "duplicate words detected, shrinking matrix size from %i to %i",
#    2073         kv.vectors.shape[0], len(kv),
#    2074     )
#
# File ~/miniconda3/lib/python3.11/site-packages/gensim/models/keyedvectors.py:1974, in _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#    1972 if line == b'':
#    1973     raise EOFError("unexpected end of input; is count incorrect or file otherwise damaged?")
# -> 1974 word, weights = _word2vec_line_to_vector(line, datatype, unicode_errors, encoding)
#    1975 _add_word_to_kv(kv, counts, word, weights, vocab_size)
#
# File ~/miniconda3/lib/python3.11/site-packages/gensim/models/keyedvectors.py:1980, in _word2vec_line_to_vector(line, datatype, unicode_errors, encoding)
#    1978 def _word2vec_line_to_vector(line, datatype, unicode_errors, encoding):
#    1979     parts = utils.to_unicode(line.rstrip(), encoding=encoding, errors=unicode_errors).split(" ")
# -> 1980     word, weights = parts[0], [datatype(x) for x in parts[1:]]
#    1981     return word, weights
#
# File ~/miniconda3/lib/python3.11/site-packages/gensim/models/keyedvectors.py:1980, in <listcomp>(.0)
#    1978 def _word2vec_line_to_vector(line, datatype, unicode_errors, encoding):
#    1979     parts = utils.to_unicode(line.rstrip(), encoding=encoding, errors=unicode_errors).split(" ")
# -> 1980     word, weights = parts[0], [datatype(x) for x in parts[1:]]
#    1981     return word, weights
#
# KeyboardInterrupt:

# %%
# if you look up an individual word， it will return the semantic vector
model["人"]
# Out:
# array([-1.419e-01,  7.040e-02,  4.526e-01, -1.260e-01,  4.830e-02,
#         1.430e-02, -1.023e-01, -5.760e-02,  4.770e-02,  5.000e-04,
#         1.910e-02,  9.650e-02,  4.850e-02, -1.361e-01,  3.510e-02,
#         5.050e-02, -3.300e-03, -3.230e-02, -2.930e-02, -9.220e-02,
#         1.740e-02, -3.000e-03, -1.290e-02, -1.780e-02,  1.045e-01,
#        -4.590e-02,  1.355e-01,  5.930e-02,  3.780e-02,  3.700e-02,
#        -1.330e-02, -2.950e-02, -6.500e-03,  1.880e-02, -2.005e-01,
#        -4.630e-02, -7.030e-02, -1.343e-01, -2.600e-02,  3.700e-03,
#        -7.230e-02, -7.980e-02,  6.500e-03, -1.563e-01, -1.182e-01,
#         6.890e-02, -5.220e-02, -2.920e-02,  8.610e-02,  3.390e-02,
#        -7.130e-02,  7.220e-02,  2.830e-02, -9.450e-02, -3.400e-03,
#         4.360e-02, -9.400e-03,  2.460e-02, -2.100e-02, -7.980e-02,
#        -7.920e-02, -1.823e-01, -7.840e-02,  3.750e-02,  1.560e-02,
#         2.800e-03, -4.840e-02,  5.720e-02, -1.470e-02,  3.910e-02,
#        -4.390e-02,  5.420e-02,  3.630e-02, -4.700e-02,  2.398e-01,
#         4.720e-02,  1.670e-02,  4.130e-02,  5.960e-02, -9.940e-02,
#        -9.770e-02, -7.270e-02,  3.030e-02,  4.820e-02,  1.890e-02,
#         4.230e-02,  1.945e-01,  4.900e-03,  5.530e-02, -1.340e-01,
#         1.818e-01,  2.110e-02, -1.030e-01, -2.500e-03,  9.410e-02,
#         7.960e-02,  4.000e-04, -3.730e-02,  7.650e-02, -1.430e-01,
#        -8.680e-02,  4.300e-02, -1.330e-02,  1.200e-03,  1.204e-01,
#         1.840e-02, -4.810e-02,  3.650e-02, -3.490e-02,  1.145e-01,
#        -1.900e-03,  8.300e-02, -6.660e-02,  3.590e-02,  3.520e-02,
#         5.250e-02, -2.530e-02,  2.990e-02, -1.100e-01,  7.630e-02,
#         1.346e-01,  5.980e-02,  2.050e-02,  6.490e-02, -5.200e-02,
        noun_vectors.append(vector)
    except:
        vector = []
        noun_vectors.append(None)
    # noun_vectors.append(vector)

# %%
noun_mw_df["noun_semantics"] = noun_vectors

# %%
noun_mw_df.head()
# Out:
#   Noun MW  Count_Pre  Count_Post  \
# 0   上午  日          1           0
# 1   下半  局          1           0
# 2   下旬  年          1           0
# 3   下旬  月          2           0
# 4   下颌  个          1           0
#
#                                       noun_semantics
# 0  [0.0198, -0.0406, 0.4887, -0.0755, -0.038, 0.1...
# 1  [0.0306, 0.0379, 0.4806, 0.0162, 0.1408, -0.12...
# 2  [0.1047, -0.0735, 0.5682, 0.056, 0.0032, -0.05...
# 3  [0.1047, -0.0735, 0.5682, 0.056, 0.0032, -0.05...
# 4  [0.3003, -0.3533, 0.2598, -0.1818, 0.2832, -0....

# %% [markdown]
# ## Calculate MW Centroids

# %%
# Re-arrange dataframe to have arrays of nouns with their corresponding MW 
# We do this for easy computation of centroids 

noun_dict = noun_mw_df.groupby('MW')['Noun'].apply(list).to_dict()
noun_dict
# Out:
# {'世': ['喇嘛', '活佛'],
#  '世纪': ['中叶', '前期', '后期', '年代', '文学', '早期', '期'],
#  '个': ['下颌',
#   '世纪',
#   '个',
#   '中学',
#   '中心',
#   '主意',
#   '主角',
#   '义项',
#   '乐团',
#   '乡',
#   '乡镇',
#   '事实',
#   '井字',
#   '产物',
#   '亲王',
#   '人',
#   '人物',
#   '人选',
#   '从句',
#   '仪式',
#   '任务',
#   '企业',
#   '会',
#   '传统',
#   '传说',
#   '伯爵',
#   '例子',
#   '保障',
#   '俱乐部',
#   '儿子',
#   '元件',
#   '元素',
#   '公司',
#   '公园',
#   '公国',
#   '公寓',
#   '公式',
#   '公爵',
#   '关系',
#   '军团',
#   '冠军',
#   '分支',
#   '分站',
#   '分类',
#   '别名',
#   '副本',
#   '力量',
#   '化石',
#   '区划',
#   '区域',
#   '单位',
#   '历史',
#   '原因',
#   '原子',
#   '原理',
#   '县',
#   '参考',
#   '反例',
#   '反应',
#   '受体',
#   '变数',
#   '变调',
#   '叛徒',
#   '名号',
#   '名字',
#   '名词',
#   '吻',
#   '哥哥',
#   '因素',
#   '团体',
#   '国家',
#   '圆弧',
#   '地区',
#   '地方',
#   '地点',
#   '城市',
#   '城镇',
#   '堂区',
#   '堂弟',
#   '壮汉',
#   '声道',
#   '夜晚',
#   '头槌',
#   '奖品',
#   '女儿',
#   '女眷',
#   '好手',
#   '妹妹',
#   '姐妹',
#   '姐姐',
#   '婚姻',
#   '子夜',
#   '字',
#   '字母',
#   '孤岛',
#   '学位',
#   '学期',
#   '学科',
#   '学院',
#   '孩子',
#   '宇宙',
#   '宗教',
#   '定理',
#   '宝藏',
#   '实体',
#   '家庭',
#   '家族',
#   '对象',
#   '导演',
#   '导航',
#   '小体',
#   '小孩',
#   '小岛',
#   '小时',
#   '小组',
#   '小调',
#   '小镇',
#   '少女',
#   '尾部',
#   '屋苑',
#   '展览',
#   '属',
#   '山区',
#   '山村',
#   '岛',
#   '州',
#   '州份',
#   '工作',
#   '工党',
#   '市场',
#   '市镇',
#   '席位',
#   '平台',
#   '年',
#   '年代',
#   '广场',
#   '庄园',
#   '形态',
#   '性腺',
#   '总理',
#   '情节',
#   '惯例',
#   '愿望',
#   '戏子',
#   '成员',
#   '战士',
#   '投票',
#   '报告',
#   '按键',
#   '提示',
#   '插曲',
#   '支派',
#   '政府',
#   '故事',
#   '教区',
#   '教授',
#   '教派',
#   '数据',
#   '新闻',
#   '方向',
#   '方法',
#   '族群',
#   '时代',
#   '时候',
#   '时间',
#   '星期',
#   '景点',
#   '曾孙',
#   '月',
#   '月台',
#   '朝代',
#   '期间',
#   '术语',
#   '机位',
#   '机关',
#   '机构',
#   '村',
#   '条约',
#   '标志',
#   '标本',
#   '校区',
#   '格',
#   '楼层',
#   '楼梯',
#   '概念',
#   '模具',
#   '模型',
#   '模腔',
#   '母亲',
#   '母音',
#   '民族',
#   '水雷',
#   '泳滩',
#   '活动',
#   '派别',
#   '游戏',
#   '湖泊',
#   '炸药',
#   '烟枪',
#   '父亲',
#   '版本',
#   '物种',
#   '物质',
#   '特工',
#   '犬种',
#   '猜想',
#   '玩具',
#   '班机',
#   '球员',
#   '球季',
#   '理想',
#   '理论',
#   '电场',
#   '男',
#   '男人',
#   '男孩',
#   '男爵',
#   '病人',
#   '目标',
#   '直径',
#   '矿场',
#   '社会',
#   '社区',
#   '祭司',
#   '种',
#   '科系',
#   '租客',
#   '称号',
#   '窑洞',
#   '立面',
#   '站点',
#   '笑话',
#   '符号',
#   '策略',
#   '管子',
#   '米利特',
#   '类',
#   '类型',
#   '粒子',
#   '系统',
#   '线索',
#   '组像',
#   '组织',
#   '细节',
#   '结果',
#   '绰号',
#   '缺点',
#   '网站',
#   '群体',
#   '群落',
#   '老师',
#   '老鼠',
#   '职位',
#   '联盟',
#   '脚趾',
#   '臣子',
#   '节目',
#   '范围',
#   '草甸',
#   '行动',
#   '行政',
#   '行星',
#   '行省',
#   '街道',
#   '裂缝',
#   '装置',
#   '角色',
#   '解答',
#   '警察',
#   '计划',
#   '议席',
#   '记录',
#   '词',
#   '词汇',
#   '词语',
#   '课题',
#   '谜',
#   '象征',
#   '贵族',
#   '赛季',
#   '车站',
#   '转变',
#   '软体',
#   '边',
#   '运动',
#   '进球',
#   '选区',
#   '遗址',
#   '邻域',
#   '郡',
#   '部件',
#   '部位',
#   '部分',
#   '部落',
#   '酒馆',
#   '铸件',
#   '锦标',
#   '镇',
#   '门洞',
#   '问题',
#   '间碟',
#   '阶段',
#   '限期',
#   '雕像',
#   '雕塑',
#   '顶部',
#   '预测',
#   '领地',
#   '领域',
#   '频道',
#   '骑士',
#   '骨头',
#   '高地',
#   '高炉'],
#  '个个': ['体系'],
#  '代': ['君主', '君王', '女皇', '版本', '男爵', '皇帝', '码头'],
#  '件': ['事', '作品', '物品', '玉衣', '珍品'],
#  '任': ['府尹', '总理', '总督', '总统', '情人', '皇帝', '署长', '首相'],
#  '份': ['俸禄', '合同', '拷贝', '遗嘱'],
#  '位': ['人员',
#   '人物',
#   '信徒',
#   '同工',
#   '同行',
#   '向导',
#   '女孩',
#   '女王',
#   '好友',
#   '妻子',
#   '娃娃',
#   '学士',
#   '孩子',
#   '将军',
#   '小姐',
#   '市长',
#   '总统',
#   '成员',
#   '教徒',
#   '旧友',
#   '歌人',
#   '歌手',
#   '法老',
#   '状元',
#   '画家',
#   '编剧',
#   '老将',
#   '老师',
#   '考生',
#   '船长',
#   '部长',
#   '长老',
#   '阿妈',
#   '院士',
#   '青年',
#   '骑士'],
#  '元': ['拨款', '货品'],
#  '公里': ['北部'],
#  '册': ['书'],
#  '分': ['宗室'],
#  '则': ['故事', '童话'],
#  '匹': ['马'],
#  '双': ['眼睛'],
#  '口': ['汤'],
#  '句': ['对话', '标语', '短语', '话'],
#  '只': ['怪兽', '手脚', '旅鸽', '熊猫', '锅', '青蛙'],
#  '台': ['汽车', '火箭', '相机', '系统'],
#  '名': ['乘客',
#   '人员',
#   '人物',
#   '代表',
#   '份子',
#   '儿子',
#   '儿童',
#   '军人',
#   '分子',
#   '博客',
#   '司铎',
#   '商人',
#   '士兵',
#   '女性',
#   '女郎',
#   '妇女',
#   '子女',
#   '少尉',
#   '居民',
#   '工人',
#   '市民',
#   '律师',
#   '成人',
#   '教授',
#   '歌星',
#   '法官',
#   '海盗',
#   '牙医',
#   '球员',
#   '球迷',
#   '男婴',
#   '男子',
#   '男童',
#   '被告',
#   '观众',
#   '议长',
#   '选手',
#   '队员',
#   '雇员'],
#  '吨': ['能力'],
#  '呎': ['吋'],
#  '周': ['冠军'],
#  '周年': ['校庆'],
#  '回': ['重播', '首播'],
#  '场': ['出赛',
#   '大火',
#   '意外',
#   '战争',
#   '战役',
#   '攻击',
#   '旱灾',
#   '梦',
#   '比赛',
#   '浩劫',
#   '演出',
#   '秀',
#   '联赛',
#   '赛事',
#   '起义',
#   '饥荒'],
#  '块': ['土地', '蛋糕', '飞地'],
#  '壶': ['酒'],
#  '处': ['中心'],
#  '天': ['抵抗'],
#  '夸脱': ['牛奶'],
#  '套': ['主机', '制度', '字母', '方法', '游戏', '电影'],
#  '季': ['收视', '结局', '集'],
#  '宗': ['私刑'],
#  '家': ['企业',
#   '俱乐部',
#   '公司',
#   '医院',
#   '场所',
#   '媒体',
#   '字号',
#   '机构',
#   '杂志',
#   '组织',
#   '银行',
#   '饭店'],
#  '对': ['对手', '尾须'],
#  '封': ['信'],
#  '尊': ['佛像', '雕像'],
#  '小段': ['对话'],
#  '小片': ['地区'],
#  '局': ['下半'],
#  '层': ['楼', '油脂', '浪', '皮毛', '碳纸', '空间'],
#  '层级': ['单位'],
#  '届': ['二中全会', '会议', '大会', '头衔', '委员', '影帝', '比赛', '赛事'],
#  '岁': ['人口', '妻子', '男童', '高龄'],
#  '帮': ['劫匪'],
#  '幅': ['地图', '画'],
#  '幢': ['塔楼', '大楼'],
#  '平方呎': ['树林'],
#  '年': ['下旬',
#   '中旬',
#   '事件',
#   '人口',
#   '任期',
#   '余额',
#   '十八大',
#   '历史',
#   '合约',
#   '名单',
#   '周期',
#   '夏',
#   '夏天',
#   '夏季',
#   '大奖',
#   '大选',
#   '季',
#   '年',
#   '年中',
#   '年初',
#   '度',
#   '形象',
#   '徒刑',
#   '战争',
#   '数目',
#   '日',
#   '时间',
#   '春',
#   '春天',
#   '春日',
#   '普查',
#   '月',
#   '期间',
#   '条约',
#   '正月',
#   '比赛',
#   '汇率',
#   '法案',
#   '点',
#   '球季',
#   '电影',
#   '秋',
#   '纪念',
#   '结果',
#   '调查',
#   '选举',
#   '金杯',
#   '陷落',
#   '革命'],
#  '年代': ['中期', '初期', '前期', '后期', '早期', '末期'],
#  '座': ['书院',
#   '亭',
#   '仓库',
#   '会堂',
#   '佛像',
#   '佛殿',
#   '便门',
#   '别墅',
#   '城堡',
#   '城市',
#   '城门',
#   '大堂',
#   '大楼',
#   '寺院',
#   '屏风',
#   '山峰',
#   '建筑',
#   '拱桥',
#   '教堂',
#   '桥',
#   '楼房',
#   '殿堂',
#   '水库',
#   '温泉',
#   '监狱',
#   '神庙',
#   '窟檐'],
#  '座座': ['冰峰'],
#  '张': ['专辑', '单曲', '唱片', '大碟', '底片', '桌', '照片', '画作'],
#  '所': ['中学', '分校', '大学', '学校', '学院', '房子', '技校', '教堂', '机构', '院校', '高校'],
#  '手': ['袖箭'],
#  '批': ['公司', '单位', '建筑', '教区', '零部件', '项目'],
#  '把': ['利刃'],
#  '挺': ['机枪'],
#  '支': ['乐队', '军队', '力量', '国旗', '民兵', '班卓', '球会', '部队', '队伍'],
#  '方': ['波折'],
#  '日': ['上午', '人次', '夜', '日', '时', '晚上', '晚间', '点'],
#  '时': ['分'],
#  '月': ['下旬',
#   '中旬',
#   '夜',
#   '政争',
#   '日',
#   '时',
#   '晚间',
#   '月',
#   '点',
#   '生日',
#   '起义',
#   '革命',
#   '风暴'],
#  '期': ['地库', '工程'],
#  '本': ['书'],
#  '条': ['出路',
#   '大道',
#   '巴士',
#   '村落',
#   '楼梯',
#   '横带',
#   '款',
#   '河',
#   '河川',
#   '河流',
#   '渠道',
#   '溪流',
#   '爬梯',
#   '球道',
#   '直线',
#   '线',
#   '线路',
#   '线道',
#   '航线',
#   '船',
#   '街',
#   '跑道',
#   '路',
#   '路线',
#   '边',
#   '道路',
#   '隧道',
#   '频道',
#   '马路'],
#  '枚': ['星章', '炸弹', '牙齿', '犬齿', '臼齿', '门齿', '飞弹', '鱼雷'],
#  '架': ['飞机'],
#  '栋': ['公寓', '建筑'],
#  '档': ['节目'],
#  '桩': ['善事', '婚事', '婚姻'],
#  '棵': ['松树', '柏树'],
#  '次': ['东征',
#   '争议',
#   '事件',
#   '事故',
#   '亚军',
#   '会议',
#   '会面',
#   '内战',
#   '冠军',
#   '分工',
#   '助攻',
#   '发酵',
#   '变革',
#   '叛乱',
#   '大会',
#   '大战',
#   '委员',
#   '婚姻',
#   '惨败',
#   '战争',
#   '战役',
#   '抗议',
#   '抽检',
#   '挖掘',
#   '改革',
#   '攻势',
#   '条约',
#   '标售',
#   '比赛',
#   '游行',
#   '爆炸',
#   '电池',
#   '盟',
#   '相遇',
#   '破坏',
#   '纪录',
#   '行动',
#   '行程',
#   '表现',
#   '袭击',
#   '调沙',
#   '谈判',
#   '进攻',
#   '远航',
#   '选举',
#   '采访',
#   '问题',
#   '风波'],
#  '款': ['巴士', '技术', '游戏'],
#  '段': ['历史', '恩怨', '文字', '时间', '期间', '短剧', '视频', '谈话', '谚言', '车程', '隐语'],
#  '毫米': ['汞柱'],
#  '派': ['势力'],
#  '片': ['争议', '土地', '椰林'],
#  '版': ['娘舅'],
#  '班': ['人士', '航班', '青年'],
#  '番': ['努力', '唇枪舌剑', '整合', '犹豫'],
#  '磅': ['乳酪'],
#  '种': ['中药',
#   '主机',
#   '乔木',
#   '习俗',
#   '交换',
#   '人',
#   '作法',
#   '作物',
#   '作用',
#   '信仰',
#   '偏激',
#   '做法',
#   '元素',
#   '光纤',
#   '关系',
#   '分子',
#   '分期',
#   '分析',
#   '制度',
#   '剑羚',
#   '区分',
#   '历程',
#   '基因',
#   '外套',
#   '威胁',
#   '工具',
#   '差异',
#   '平衡',
#   '幸福',
#   '形式',
#   '形象',
#   '快感',
#   '情况',
#   '情感',
#   '感觉',
#   '成份',
#   '技术',
#   '报道',
#   '效果',
#   '文化',
#   '文字',
#   '新星',
#   '方式',
#   '方法',
#   '机制',
#   '材料',
#   '条件',
#   '植物',
#   '模式',
#   '模样',
#   '款式',
#   '武器',
#   '死亡',
#   '氨基酸',
#   '水果',
#   '波动',
#   '波长',
#   '流感',
#   '游戏',
#   '灾害',
#   '燃气',
#   '爱好',
#   '物质',
#   '特性',
#   '状态',
#   '现象',
#   '理论',
#   '生物',
#   '疾病',
#   '病',
#   '病毒',
#   '米',
#   '类型',
#   '系统',
#   '组件',
#   '细胞',
#   '结构',
#   '肉',
#   '舞蹈',
#   '茶叶',
#   '荷尔蒙',
#   '菌',
#   '虚拟',
#   '融合',
#   '行为',
#   '见解',
#   '观点',
#   '视图',
#   '解释',
#   '认知',
#   '词素',
#   '词缀',
#   '语言',
#   '转变',
#   '运动',
#   '递归',
#   '遗物',
#   '部队',
#   '金币',
#   '阶层',
#   '障碍',
#   '音乐',
#   '颈部',
#   '颜色',
#   '风尚',
#   '饮品',
#   '鸟类'],
#  '笔': ['交易'],
#  '篇': ['文章', '论文', '诗篇'],
#  '米': ['水深', '海拔', '赛事'],
#  '类': ['动画', '植物', '横波'],
#  '级': ['台阶'],
#  '纪元': ['年'],
#  '组': ['列车', '数字', '神', '符号'],
#  '群': ['人', '组合', '部落'],
#  '艘': ['战舰', '潜艇'],
#  '行': ['人', '直间'],
#  '记': ['耳光'],
#  '起': ['动乱', '案件', '纠纷'],
#  '轮': ['攻击', '顺位'],
#  '辆': ['巴士', '机车', '车', '车辆'],
#  '连串': ['状况'],
#  '通': ['电话'],
#  '道': ['工序', '条', '横线', '沟壑'],
#  '部': ['书',
#   '作品',
#   '农书',
#   '剧本',
#   '剧集',
#   '小说',
#   '巨作',
#   '故事',
#   '曲',
#   '游戏',
#   '电影',
#   '电梯',
#   '电脑',
#   '舞剧',
#   '货车'],
#  '重': ['从句', '特性', '间碟'],
#  '间': ['中心', '公司', '分店', '单位', '商店', '学校', '房屋', '房间', '洋房', '球会', '课室', '银行'],
#  '集': ['书'],
#  '面': ['奖牌'],
#  '项': ['主张',
#   '分析',
#   '判决',
#   '工业',
#   '工程',
#   '改革',
#   '权利',
#   '权益',
#   '死刑',
#   '比赛',
#   '法案',
#   '研究',
#   '立法',
#   '行动',
#   '计划',
#   '设计',
#   '项目'],
#  '颗': ['卫星', '子球', '新星', '星', '星章', '眼睛', '蛋', '行星'],
#  '首': ['新作', '曲', '歌', '诗歌']}

# %%
# Calculate centroids
# Note that this noramlizes the centroids (don't fully understand that but chatgpt recommends it)

mw_centroids = {}

for mw, words in noun_dict.items():
    vectors = []
    for word in words:
        if word in model:
            vectors.append(model[word])
    if vectors:
        centroid = np.mean(vectors, axis=0)
        # centroid = centroid / np.linalg.norm(centroid) # Centroid Normalization line
        mw_centroids[mw] = centroid

# %%
# Add centroids back into the main df
noun_mw_df['MW_centroid'] = noun_mw_df['MW'].map(mw_centroids)

# %%
noun_mw_df.head()
# Out:
#   Noun MW  Count_Pre  Count_Post  \
# 0   上午  日          1           0
# 1   下半  局          1           0
# 2   下旬  年          1           0
# 3   下旬  月          2           0
# 4   下颌  个          1           0
#
#                                       noun_semantics  \
# 0  [0.0198, -0.0406, 0.4887, -0.0755, -0.038, 0.1...
# 1  [0.0306, 0.0379, 0.4806, 0.0162, 0.1408, -0.12...
# 2  [0.1047, -0.0735, 0.5682, 0.056, 0.0032, -0.05...
# 3  [0.1047, -0.0735, 0.5682, 0.056, 0.0032, -0.05...
# 4  [0.3003, -0.3533, 0.2598, -0.1818, 0.2832, -0....
#
#                                          MW_centroid
# 0  [0.0308, -0.023712497, 0.4776, -0.028487498, -...
# 1  [0.0306, 0.0379, 0.4806, 0.0162, 0.1408, -0.12...
# 2  [0.016535418, 0.040139582, 0.51436454, -0.0627...
# 3  [0.057184614, 0.03014615, 0.4474923, -0.003700...
# 4  [-0.006889136, 0.022415332, 0.46960655, -0.039...

# %% [markdown]
# # Cosine Similarity/Distance Values

# %%
# Calculate Cosine similarity between the given noun and the MW
# Higher value = more similar

def cosine_similarity(vec1, vec2):
    if (vec1 is None or vec2 is None or 
        len(vec1) != 300 or len(vec2) != 300):
        return np.nan
    return dot(vec1, vec2) / (norm(vec1) * norm(vec2))
    
noun_mw_df['cosine_sim'] = noun_mw_df.apply(
    lambda row: cosine_similarity(row['noun_semantics'], row['MW_centroid']),
    axis=1
)

# %%
noun_mw_df.head()
# Out:
#   Noun MW  Count_Pre  Count_Post  \
# 0   上午  日          1           0
# 1   下半  局          1           0
# 2   下旬  年          1           0
# 3   下旬  月          2           0
# 4   下颌  个          1           0
#
#                                       noun_semantics  \
# 0  [0.0198, -0.0406, 0.4887, -0.0755, -0.038, 0.1...
# 1  [0.0306, 0.0379, 0.4806, 0.0162, 0.1408, -0.12...
# 2  [0.1047, -0.0735, 0.5682, 0.056, 0.0032, -0.05...
# 3  [0.1047, -0.0735, 0.5682, 0.056, 0.0032, -0.05...
# 4  [0.3003, -0.3533, 0.2598, -0.1818, 0.2832, -0....
#
#                                          MW_centroid  cosine_sim
# 0  [0.0308, -0.023712497, 0.4776, -0.028487498, -...    0.753960
# 1  [0.0306, 0.0379, 0.4806, 0.0162, 0.1408, -0.12...    1.000000
# 2  [0.016535418, 0.040139582, 0.51436454, -0.0627...    0.539342
# 3  [0.057184614, 0.03014615, 0.4474923, -0.003700...    0.645733
# 4  [-0.006889136, 0.022415332, 0.46960655, -0.039...    0.427536

# %% [markdown]
# ## Save Noun Semantics

# %%
noun_semantics_df = noun_mw_df
noun_semantics_df = noun_semantics_df[["Noun", "Count_Pre"]]
noun_semantics_df = noun_semantics_df.groupby(['Noun'], as_index=False).sum()

# Initialize a list to store the corresponding noun_semantics
noun_semantics_list = []

# Loop through each row in the test DataFrame
for _, row in noun_semantics_df.iterrows():
    noun = row['Noun']
    
    # Find the first matching row in noun_mw_df for the current noun
    matching_row = noun_mw_df[noun_mw_df['Noun'] == noun].iloc[0]
    
    # Append the noun_semantics value to the list
    noun_semantics_list.append(matching_row['noun_semantics'])

# Add the noun_semantics values as a new column to the test DataFrame
noun_semantics_df['noun_semantics'] = noun_semantics_list

noun_semantics_df = noun_semantics_df.rename(columns={"Noun": "noun", "Count_Pre": "count"})

# %%
noun_semantics_df.head()
# Out:
#   noun  count                                     noun_semantics
# 0   上午      1  [0.0198, -0.0406, 0.4887, -0.0755, -0.038, 0.1...
# 1   下半      1  [0.0306, 0.0379, 0.4806, 0.0162, 0.1408, -0.12...
# 2   下旬      3  [0.1047, -0.0735, 0.5682, 0.056, 0.0032, -0.05...
# 3   下颌      1  [0.3003, -0.3533, 0.2598, -0.1818, 0.2832, -0....
# 4   专辑      6  [-0.186, -0.0423, 0.4913, 0.1851, 0.0968, -0.0...

# %%
noun_semantics_df.to_csv('output/noun_semantics_df.csv')
noun_semantics_df.to_pickle("output/noun_semantics.pkl")

# %% [markdown]
# ## Save MW Semantics

# %%
mw_semantics_df = noun_mw_df
mw_semantics_df = mw_semantics_df[["MW", "Count_Pre", "MW_centroid"]]
mw_semantics_df.head()
# Out:
#   MW  Count_Pre                                        MW_centroid
# 0  日          1  [0.0308, -0.023712497, 0.4776, -0.028487498, -...
# 1  局          1  [0.0306, 0.0379, 0.4806, 0.0162, 0.1408, -0.12...
# 2  年          1  [0.016535418, 0.040139582, 0.51436454, -0.0627...
# 3  月          2  [0.057184614, 0.03014615, 0.4474923, -0.003700...
# 4  个          1  [-0.006889136, 0.022415332, 0.46960655, -0.039...

# %%
# Calculate actual MW values

mw_semantics = []

for _, row in mw_semantics_df.iterrows():
    noun = row['MW']
    try:
        vector = model[mw]
        mw_semantics.append(vector)
    except:
        mw_semantics.append(None)

# %%
mw_semantics_df["mw_semantics"] = mw_semantics
# Out:
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_43431/146520131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mw_semantics_df["mw_semantics"] = mw_semantics

# %%
mw_semantics_df.head()
# Out:
#   MW  Count_Pre                                        MW_centroid  \
# 0  日          1  [0.0308, -0.023712497, 0.4776, -0.028487498, -...
# 1  局          1  [0.0306, 0.0379, 0.4806, 0.0162, 0.1408, -0.12...
# 2  年          1  [0.016535418, 0.040139582, 0.51436454, -0.0627...
# 3  月          2  [0.057184614, 0.03014615, 0.4474923, -0.003700...
# 4  个          1  [-0.006889136, 0.022415332, 0.46960655, -0.039...
#
#                                         mw_semantics
# 0  [0.1245, -0.0269, 0.4524, 0.1575, 0.01, -0.048...
# 1  [0.1245, -0.0269, 0.4524, 0.1575, 0.01, -0.048...
# 2  [0.1245, -0.0269, 0.4524, 0.1575, 0.01, -0.048...
# 3  [0.1245, -0.0269, 0.4524, 0.1575, 0.01, -0.048...
# 4  [0.1245, -0.0269, 0.4524, 0.1575, 0.01, -0.048...

# %%
mw_semantics_df.to_csv('output/mw_semantics_df.csv')
mw_semantics_df.to_pickle("output/mw_semantics.pkl")

# %% [markdown]
# ## Plots

# %%
# 1. Filter out the rows where MW == "个"
plot_df = noun_mw_df[noun_mw_df['MW'] != "个"].copy()

# 2. Drop rows with missing vectors or invalid dimensions
plot_df = plot_df.dropna(subset=['noun_semantics'])
plot_df = plot_df[plot_df['noun_semantics'].apply(lambda x: len(x) == 300)]

# 3. Stack vectors into a matrix for PCA
X = np.vstack(plot_df['noun_semantics'].values)

# 4. Run PCA (using 2 components for 2D visualization)
pca = PCA(n_components=2)
X_2d = pca.fit_transform(X)

# 5. Add PCA results to DataFrame
plot_df['pca_x'] = X_2d[:, 0]
plot_df['pca_y'] = X_2d[:, 1]

# 6. Plot
plt.figure(figsize=(10, 8))
groups = plot_df.groupby('MW')

for name, group in groups:
    plt.scatter(group['pca_x'], group['pca_y'], label=name, alpha=0.6)

# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='MW')
plt.title("PCA of Noun Semantics by MW (excluding '个')")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/3270163396.py:30: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from current font.
#   plt.tight_layout()
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 1. Filter out the rows where MW == "个"
plot_df = noun_mw_df[noun_mw_df['MW'] != "个"].copy()

# 2. Drop rows with missing vectors or invalid dimensions
plot_df = plot_df.dropna(subset=['noun_semantics'])
plot_df = plot_df[plot_df['noun_semantics'].apply(lambda x: len(x) == 300)]  # Ensure vectors have the correct length

# 3. Stack vectors into a matrix for t-SNE
X = np.vstack(plot_df['noun_semantics'].values)

# 4. Run t-SNE (using 2 components for 2D visualization)
tsne = TSNE(n_components=2, random_state=42, init='pca', perplexity=30)
X_2d = tsne.fit_transform(X)

# 5. Add t-SNE results to DataFrame
plot_df['tsne_x'] = X_2d[:, 0]
plot_df['tsne_y'] = X_2d[:, 1]

# 6. Get a list of unique MWs and assign a color palette
unique_mws = plot_df['MW'].unique()
colors = sns.color_palette("tab20", len(unique_mws))  # Use a larger, distinct colormap

# 7. Create a dictionary to map MWs to colors
mw_to_color = {mw: colors[i % len(colors)] for i, mw in enumerate(unique_mws)}  # Ensures uniqueness with modulo

# 8. Plot
plt.figure(figsize=(10, 8))

# Loop through MW groups and plot with unique color
for name, group in plot_df.groupby('MW'):
    plt.scatter(group['tsne_x'], group['tsne_y'], label=name, alpha=0.6, color=mw_to_color[name])

plt.title("t-SNE of Noun Semantics by MW (excluding '个')")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='MW', fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 19990 (\N{CJK UNIFIED IDEOGRAPH-4E16}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 32426 (\N{CJK UNIFIED IDEOGRAPH-7EAA}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20219 (\N{CJK UNIFIED IDEOGRAPH-4EFB}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20221 (\N{CJK UNIFIED IDEOGRAPH-4EFD}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20301 (\N{CJK UNIFIED IDEOGRAPH-4F4D}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20803 (\N{CJK UNIFIED IDEOGRAPH-5143}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 37324 (\N{CJK UNIFIED IDEOGRAPH-91CC}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20876 (\N{CJK UNIFIED IDEOGRAPH-518C}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 21017 (\N{CJK UNIFIED IDEOGRAPH-5219}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 21305 (\N{CJK UNIFIED IDEOGRAPH-5339}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 21452 (\N{CJK UNIFIED IDEOGRAPH-53CC}) missing from current font.
#   plt.tight_layout()
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_54714/2960682451.py:37: UserWarning: Glyph 
) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23618 (\N{CJK UNIFIED IDEOGRAPH-5C42}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32423 (\N{CJK UNIFIED IDEOGRAPH-7EA7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23626 (\N{CJK UNIFIED IDEOGRAPH-5C4A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23681 (\N{CJK UNIFIED IDEOGRAPH-5C81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24110 (\N{CJK UNIFIED IDEOGRAPH-5E2E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24133 (\N{CJK UNIFIED IDEOGRAPH-5E45}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24162 (\N{CJK UNIFIED IDEOGRAPH-5E62}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26041 (\N{CJK UNIFIED IDEOGRAPH-65B9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24231 (\N{CJK UNIFIED IDEOGRAPH-5EA7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24352 (\N{CJK UNIFIED IDEOGRAPH-5F20}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25152 (\N{CJK UNIFIED IDEOGRAPH-6240}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25163 (\N{CJK UNIFIED IDEOGRAPH-624B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25209 (\N{CJK UNIFIED IDEOGRAPH-6279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25226 (\N{CJK UNIFIED IDEOGRAPH-628A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25402 (\N{CJK UNIFIED IDEOGRAPH-633A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25903 (\N{CJK UNIFIED IDEOGRAPH-652F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26465 (\N{CJK UNIFIED IDEOGRAPH-6761}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26522 (\N{CJK UNIFIED IDEOGRAPH-679A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26550 (\N{CJK UNIFIED IDEOGRAPH-67B6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26635 (\N{CJK UNIFIED IDEOGRAPH-680B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26723 (\N{CJK UNIFIED IDEOGRAPH-6863}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26729 (\N{CJK UNIFIED IDEOGRAPH-6869}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26869 (\N{CJK UNIFIED IDEOGRAPH-68F5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27454 (\N{CJK UNIFIED IDEOGRAPH-6B3E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27627 (\N{CJK UNIFIED IDEOGRAPH-6BEB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31859 (\N{CJK UNIFIED IDEOGRAPH-7C73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27966 (\N{CJK UNIFIED IDEOGRAPH-6D3E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29256 (\N{CJK UNIFIED IDEOGRAPH-7248}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29677 (\N{CJK UNIFIED IDEOGRAPH-73ED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30058 (\N{CJK UNIFIED IDEOGRAPH-756A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30917 (\N{CJK UNIFIED IDEOGRAPH-78C5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31181 (\N{CJK UNIFIED IDEOGRAPH-79CD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31508 (\N{CJK UNIFIED IDEOGRAPH-7B14}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31687 (\N{CJK UNIFIED IDEOGRAPH-7BC7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31867 (\N{CJK UNIFIED IDEOGRAPH-7C7B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32452 (\N{CJK UNIFIED IDEOGRAPH-7EC4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32676 (\N{CJK UNIFIED IDEOGRAPH-7FA4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 33368 (\N{CJK UNIFIED IDEOGRAPH-8258}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 35760 (\N{CJK UNIFIED IDEOGRAPH-8BB0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36215 (\N{CJK UNIFIED IDEOGRAPH-8D77}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36718 (\N{CJK UNIFIED IDEOGRAPH-8F6E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36742 (\N{CJK UNIFIED IDEOGRAPH-8F86}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36830 (\N{CJK UNIFIED IDEOGRAPH-8FDE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20018 (\N{CJK UNIFIED IDEOGRAPH-4E32}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36890 (\N{CJK UNIFIED IDEOGRAPH-901A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36947 (\N{CJK UNIFIED IDEOGRAPH-9053}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 37096 (\N{CJK UNIFIED IDEOGRAPH-90E8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38598 (\N{CJK UNIFIED IDEOGRAPH-96C6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38754 (\N{CJK UNIFIED IDEOGRAPH-9762}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39033 (\N{CJK UNIFIED IDEOGRAPH-9879}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39063 (\N{CJK UNIFIED IDEOGRAPH-9897}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39318 (\N{CJK UNIFIED IDEOGRAPH-9996}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 1. Filter out the rows where MW == "个"
plot_df = noun_mw_df[noun_mw_df['MW'] != "个"].copy()

# 2. Drop rows with missing vectors or invalid dimensions
plot_df = plot_df.dropna(subset=['noun_semantics'])
plot_df = plot_df[plot_df['noun_semantics'].apply(lambda x: len(x) == 300)]  # Ensure vectors have the correct length

# 3. Stack vectors into a matrix for t-SNE
X = np.vstack(plot_df['noun_semantics'].values)

# 4. Run t-SNE (using 2 components for 2D visualization)
tsne = TSNE(n_components=2, random_state=42, init='pca', perplexity=30)
X_2d = tsne.fit_transform(X)

# 5. Add t-SNE results to DataFrame
plot_df['tsne_x'] = X_2d[:, 0]
plot_df['tsne_y'] = X_2d[:, 1]

# 6. Get a list of unique MWs and assign a color palette
unique_mws = plot_df['MW'].unique()
colors = sns.color_palette("tab20", len(unique_mws))  # Use a larger, distinct colormap

# 7. Create a dictionary to map MWs to colors
mw_to_color = {mw: colors[i % len(colors)] for i, mw in enumerate(unique_mws)}  # Ensures uniqueness with modulo

# 8. Plotting words (noun semantics)
plt.figure(figsize=(10, 8))

for name, group in plot_df.groupby('MW'):
    plt.scatter(group['tsne_x'], group['tsne_y'], label=name, alpha=0.6, color=mw_to_color[name])

# 9. Plotting MW centroids (use 'mw_centroid' column from the DataFrame)
centroid_tsne = np.vstack(plot_df.groupby('MW')['MW_centroid'].first().values)  # Getting the centroids
centroid_tsne_2d = tsne.fit_transform(centroid_tsne)

# Plot the centroids
plt.scatter(centroid_tsne_2d[:, 0], centroid_tsne_2d[:, 1], marker='X', color='black', s=100, label='Centroids', edgecolor='k')

# Add legends and labels
plt.title("t-SNE of Noun Semantics by MW (excluding '个') with MW Centroids")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='MW', fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/0f/7mr42p3n3mxc5z1g5q3267p81ryl0h/T/ipykernel_43431/867038764.py:44: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from current font.
#   plt.tight_layout()
# /Users/sp6961/miniconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Do PCA and plot

# %% [markdown]
# # Cosine Similarity

# %%
# Calculate Cosine Similarties.

# %%
from sklearn.metrics import silhouette_score

# Stack noun vectors
X = np.vstack(plot_df['noun_semantics'].values)

# Convert MWs to numeric cluster labels
from sklearn.preprocessing import LabelEncoder
labels = LabelEncoder().fit_transform(plot_df['MW'])

# Compute silhouette score
score = silhouette_score(X, labels)
print(f"Silhouette Score: {score:.3f}")
# Out:
# Silhouette Score: -0.165

# %%
# Pretty bad score, in other words, teh clusters are super overlapping

# %%
from scipy.spatial.distance import cosine

intra_dists = []
inter_dists = []

for i, row in plot_df.iterrows():
    noun_vec = row['noun_semantics']
    mw = row['MW']
    centroid = row['MW_centroid']
    
    # Intra-cluster distance
    intra = cosine(noun_vec, centroid)
    intra_dists.append(intra)
    
    # Inter-cluster distance (to centroids of other MWs)
    for other_mw, other_centroid in plot_df.groupby('MW')['MW_centroid'].first().items():
        if other_mw != mw:
            inter = cosine(noun_vec, other_centroid)
            inter_dists.append(inter)

# Compare means
import numpy as np
print(f"Mean Intra-cluster Cosine Distance: {np.mean(intra_dists):.3f}")
print(f"Mean Inter-cluster Cosine Distance: {np.mean(inter_dists):.3f}")
# Out:
# Mean Intra-cluster Cosine Distance: 0.389
# Mean Inter-cluster Cosine Distance: 0.747

# %% [markdown]
# According to chat-gpt:
# intra-cluaster should be low (0-0.3)
# inter-cluster should be high (>0.5
# a gap of bigger than 0.2 means a mennaingful clustering

# %%
from scipy.stats import ttest_ind
t_stat, p_val = ttest_ind(intra_dists, inter_dists, equal_var=False)
print(f"T-test p-value: {p_val:.5f}")
# Out:
# T-test p-value: 0.00000

# %%
noun_mw_df.to_csv('output/noun_mw_cosineSim.csv')
